# %%
import re
import pandas as pd
# seperate dataframes for wire_sources and destination and for Module and function blokcs.

# %%
path = 'C:/Users/shree/OneDrive/Desktop/UserCase/New/AltaML_FHX_SAMA_Data_Samples/Reduced_FHX_file.txt'
rawdata= open(path,'r')
data = rawdata.read()
print(data)
# Out:
# MODULE_CLASS NAME="KS_AI_STD" CATEGORY="Library/Control Module Classes/A_FieldDevice"
#  user="ADMINISTRAT0R" time=1591208430/* "03-Jun-2020 12:20:30" */
# {
#   DESCRIPTION="Standard AI with Alarms"
#   PERIOD=5
#   PRIMARY_CONTROL_DISPLAY=""
#   INSTRUMENT_AREA_DISPLAY="KS_AI_fp"
#   DETAIL_DISPLAY="KS_AI_dt"
#   TYPE="Monitor"
#   SUB_TYPE="STD_AI"
#   NVM=F
#   FUNCTION_BLOCK NAME="PV-COMPARE" DEFINITION="CALC"
#   {
#     DESCRIPTION="Calc/Logic"
#     ID=143011011
#     RECTANGLE= { X=72 Y=632 H=56 W=130 }
#     SCAN_MULTIPLIER=5
#     EXTENSIBLE_ATTRIBUTE { NAME="OUT"  COUNT=2 }
#     EXTENSIBLE_ATTRIBUTE { NAME="IN"  COUNT=1 }
#   }
#   FUNCTION_BLOCK NAME="HI_HI_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=17237850
#     RECTANGLE= { X=290 Y=110 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="HI_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=17237597
#     RECTANGLE= { X=290 Y=180 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="LO_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=17237882
#     RECTANGLE= { X=290 Y=250 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="LO_LO_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=17237924
#     RECTANGLE= { X=290 Y=320 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="AI1" DEFINITION="AIWCALARM"
#   {
#     DESCRIPTION="Analog Input"
#     ID=136708588
#     RECTANGLE= { X=620 Y=90 H=176 W=139 }
#     ADDITIONAL_CONNECTOR NAME="PV" TYPE=OUTPUT { ATTRIBUTE="PV" }
#     ADDITIONAL_CONNECTOR NAME="HI_HI_ENAB" TYPE=INPUT { ATTRIBUTE="HI_HI_ENAB" }
#     ADDITIONAL_CONNECTOR NAME="HI_ENAB" TYPE=INPUT { ATTRIBUTE="HI_ENAB" }
#     ADDITIONAL_CONNECTOR NAME="LO_ENAB" TYPE=INPUT { ATTRIBUTE="LO_ENAB" }
#     ADDITIONAL_CONNECTOR NAME="LO_LO_ENAB" TYPE=INPUT { ATTRIBUTE="LO_LO_ENAB" }
#     ATTRIBUTE_USAGE NAME="HI_HI_LIM"
#     {
#       CATEGORY { CATEGORY=COMMON }
#     }
#     ATTRIBUTE_USAGE NAME="LO_LO_LIM"
#     {
#       CATEGORY { CATEGORY=COMMON }
#     }
#   }
#   ATTRIBUTE NAME="VERSION_CLASS" TYPE=UINT32
#   {
#     READONLY=T
#     EDITABLE=F
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#     GROUP="Operating"
#     HELP_ID=337653
#     CATEGORY { CATEGORY=ONLINE }
#   }
#   ATTRIBUTE NAME="HI_HI_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="HI_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="LO_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="LO_LO_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="PVBAD_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="PID_DWG" TYPE=UNICODE_STRING
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=30 Y=140 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPER_RANGE_HI" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=32 Y=232 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPER_RANGE_LO" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=32 Y=252 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="TRACKER_OP" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=32 Y=472 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="DIR_PV_CHG" TYPE=FLOAT
#   {
#     CONNECTION=OUTPUT
#     RECTANGLE= { X=70 Y=555 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="DIR_PV_CHG_DB" TYPE=FLOAT
#   {
#     CONNECTION=OUTPUT
#     RECTANGLE= { X=72 Y=592 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="PREVIOUS_PV" TYPE=FLOAT
#   {
#     CONNECTION=OUTPUT
#     RECTANGLE= { X=72 Y=712 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPTM_RANGE_HI" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=31 Y=337 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPTM_RANGE_LO" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=31 Y=357 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="ALM_HYS" TYPE=INTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=240 Y=790 H=20 W=120 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="HI_ALM_HYS" TYPE=INTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SINK
#     RECTANGLE= { X=750 Y=830 H=20 W=120 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="HI_HI_ALM_HYS" TYPE=INTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SINK
#     RECTANGLE= { X=750 Y=790 H=20 W=120 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="LO_ALM_HYS" TYPE=INTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SINK
#     RECTANGLE= { X=750 Y=870 H=20 W=120 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="LO_LO_ALM_HYS" TYPE=INTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SINK
#     RECTANGLE= { X=750 Y=910 H=20 W=120 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="LOOP_DWG" TYPE=UNICODE_STRING
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=30 Y=160 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   FBD_ALGORITHM
#   {
#     GRAPHICS ALGORITHM=FBD
#     {
#       TEXT_GRAPHIC
#       {
#         NAME="0825FCA9"
#         ORIGIN= { X=599 Y=41 }
#         END= { X=818 Y=55 }
#         TEXT=" Analog Input monitoring module with alarms
# "
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{5ADE4BD3-C00A-486C-BEFE-7690FDB20FB0}"
#         RECTANGLE= { X=30 Y=80 H=10 W=180 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{1355024D-C5E9-40F8-B3BF-BC9155221FF6}"
#         ORIGIN= { X=36 Y=97 }
#         END= { X=200 Y=139 }
#         TEXT="This parameter is set to the P&ID
# Drawing that this equipment is
# found on."
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{0829A170-24FB-4E6D-9F6F-31F638715C57}"
#         ORIGIN= { X=36 Y=190 }
#         END= { X=164 Y=232 }
#         TEXT="Target/Operating Range
# Used to Display the Grey
# Box on the Graphics."
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{95645E77-82D9-4BB7-BAB5-8A7131774F60}"
#         RECTANGLE= { X=25 Y=400 H=10 W=185 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{0CED1249-17E9-4C7E-8531-C38318306A1F}"
#         ORIGIN= { X=36 Y=426 }
#         END= { X=173 Y=468 }
#         TEXT="Tracker/Expected Value
# Used to display line on the
# Graphic."
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{5CE10055-6295-419A-8146-8B9879F89309}"
#         RECTANGLE= { X=25 Y=500 H=10 W=185 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{2F3E1435-7437-4896-A329-95B5255B85BE}"
#         ORIGIN= { X=63 Y=513 }
#         END= { X=224 Y=558 }
#         TEXT="PV Direction Change Indication
# Used to show the up/down
# arrow on the graphics."
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{71AB3F22-C1A5-44B0-88C5-D7BCF5D6C773}"
#         ORIGIN= { X=64 Y=581 }
#         END= { X=207 Y=595 }
#         TEXT="Deadband in % of PV_SCALE"
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{36D69532-1DCA-4558-99AB-89793B681117}"
#         RECTANGLE= { X=210 Y=80 H=1110 W=10 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{8FA3E613-B22D-43F0-9E74-1A31261B9099}"
#         RECTANGLE= { X=25 Y=740 H=10 W=185 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{9A5D3C7A-6644-4DC4-8637-A0385268BBB3}"
#         RECTANGLE= { X=220 Y=740 H=10 W=1870 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{6EC7B293-AD5E-4A18-B2C8-3EEE9BC3B484}"
#         RECTANGLE= { X=980 Y=50 H=690 W=10 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{09C5EF44-E390-4285-87D1-5BC55633551F}"
#         RECTANGLE= { X=1460 Y=55 H=685 W=10 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{666DBB7E-38A9-424A-AD4E-C9E09010CA75}"
#         ORIGIN= { X=35 Y=295 }
#         END= { X=196 Y=337 }
#         TEXT="Optimal Range
# Used for Display of the upper
# and lower range on the graphic.  "
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{9AE2C65E-63A9-4A61-B048-F3CD0FFDA9CE}"
#         ORIGIN= { X=249 Y=764 }
#         END= { X=398 Y=778 }
#         TEXT="Allow only on Alarm Deadband"
#       }
#     }
#     WIRE SOURCE="ALM_HYS" DESTINATION="HI_HI_ALM_HYS"
#     {
#       ORIGIN_ID=338824837
#     }
#     WIRE SOURCE="ALM_HYS" DESTINATION="HI_ALM_HYS"
#     {
#       ORIGIN_ID=338824838
#     }
#     WIRE SOURCE="ALM_HYS" DESTINATION="LO_ALM_HYS"
#     {
#       ORIGIN_ID=338824839
#     }
#     WIRE SOURCE="ALM_HYS" DESTINATION="LO_LO_ALM_HYS"
#     {
#       ORIGIN_ID=338824840
#     }
#     WIRE SOURCE="HI_HI_ALARM/OUT_D" DESTINATION="AI1/HI_HI_ENAB"
#     {
#       ORIGIN_ID=338824841
#     }
#     WIRE SOURCE="HI_ALARM/OUT_D" DESTINATION="AI1/HI_ENAB"
#     {
#       ORIGIN_ID=338824842
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=500 }
#     }
#     WIRE SOURCE="LO_ALARM/OUT_D" DESTINATION="AI1/LO_ENAB"
#     {
#       ORIGIN_ID=338824843
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=510 }
#     }
#     WIRE SOURCE="LO_LO_ALARM/OUT_D" DESTINATION="AI1/LO_LO_ENAB"
#     {
#       ORIGIN_ID=338824844
#     }
#   }
#   ATTRIBUTE_INSTANCE NAME="MCOMMAND"
#   {
#     VALUE
#     {
#       SET="$module_states"
#       STRING_VALUE="In Service"
#       CHANGEABLE=F
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MSTATE"
#   {
#     VALUE
#     {
#       SET="$module_states"
#       STRING_VALUE="In Service"
#       CHANGEABLE=F
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MERROR"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_error_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MSTATUS"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_status_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MSTATUS_MASK"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_status_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MERROR_MASK"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_error_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="BAD_ACTIVE"
#   {
#     VALUE { CV=F }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="ABNORM_ACTIVE"
#   {
#     VALUE { CV=F }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="VERSION"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="BLOCK_ERR"
#   {
#     VALUE
#     {
#       ENUM_SET="$blk_err_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="EXEC_TIME"
#   {
#     VALUE { CV=0 }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="ONTIME"
#   {
#     VALUE { CV=F }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="VERSION_CLASS"
#   {
#     VALUE { CV=23 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=F
#       INV=F
#       ATYP="High High Alarm"
#       MONATTR=""
#       ALMATTR="AI1/HI_HI_ACT"
#       LIMATTR="AI1/HI_HI_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/HI_HI_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="MEDIUM"
#       ENAB=F
#       INV=F
#       ATYP="High Alarm"
#       MONATTR=""
#       ALMATTR="AI1/HI_ACT"
#       LIMATTR="AI1/HI_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/HI_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="MEDIUM"
#       ENAB=F
#       INV=F
#       ATYP="Low Alarm"
#       MONATTR=""
#       ALMATTR="AI1/LO_ACT"
#       LIMATTR="AI1/LO_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/LO_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=F
#       INV=F
#       ATYP="Low Low Alarm"
#       MONATTR=""
#       ALMATTR="AI1/LO_LO_ACT"
#       LIMATTR="AI1/LO_LO_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/LO_LO_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PVBAD_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=T
#       INV=F
#       ATYP="General I/O Failure"
#       MONATTR=""
#       ALMATTR="AI1/BAD_ACTIVE"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PID_DWG"
#   {
#     VALUE { CV="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPER_RANGE_HI"
#   {
#     VALUE { CV=100 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPER_RANGE_LO"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="TRACKER_OP"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="DIR_PV_CHG"
#   {
#     VALUE { CV=0 }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="DIR_PV_CHG_DB"
#   {
#     VALUE { CV=1 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PREVIOUS_PV"
#   {
#     VALUE { CV=0 }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPTM_RANGE_HI"
#   {
#     VALUE { CV=100 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPTM_RANGE_LO"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="ALM_HYS"
#   {
#     VALUE { REF="AI1/ALARM_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALM_HYS"
#   {
#     VALUE { REF="AI1/HI_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALM_HYS"
#   {
#     VALUE { REF="AI1/HI_HI_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALM_HYS"
#   {
#     VALUE { REF="AI1/LO_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALM_HYS"
#   {
#     VALUE { REF="AI1/LO_LO_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LOOP_DWG"
#   {
#     VALUE { CV="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/STATUS_OPTS"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/XD_SCALE"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/MODE"
#   {
#     VALUE
#     {
#       OOS_P=T
#       IMAN_P=F
#       LOV_P=F
#       MAN_P=F
#       AUTO_P=T
#       CAS_P=F
#       RCAS_P=F
#       ROUT_P=F
#       OOS_A=T
#       IMAN_A=F
#       LOV_A=F
#       MAN_A=T
#       AUTO_A=T
#       CAS_A=F
#       RCAS_A=F
#       ROUT_A=F
#       TARGET=AUTO
#       NORMAL=AUTO
#     }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/OUT"
#   {
#     HISTORY_DATA_POINT FIELD="CV"
#     {
#       DATA_CHARACTERISTIC=CONTINUOUS
#       ENABLED=T
#       SAMPLE_PERIOD_SECONDS=2
#       COMPRESSION_ENABLED=T
#       RECORD_AT_LEAST_EVERY_MINUTES=1440
#       DEVIATION_LIMIT_FOR_COMPRESSION=0.02
#       DATA_REPRESENTATION=AUTOMATIC
#       EXPOSED=F
#       ENTERPRISE_COLLECTION=F
#     }
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/L_TYPE"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LOW_CUT"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LIM"
#   {
#     VALUE { CV=5 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/BAD_MASK"
#   {
#     VALUE
#     {
#       ENUM_SET="$blk_err_opts"
#       OPTION8=T
#       OPTION15=T
#     }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/STDEV_LIMIT"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_HI_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LO_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_HI_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LO_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_HI_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LO_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="PV-COMPARE/T_EXPRESSION"
#   {
#     VALUE { TYPE=EXPRESSION EXPRESSION="'^/DIR_PV_CHG.CV':=0;
# DB := ('^/DIR_PV_CHG_DB.CV'/100)*('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0');
# if abs('^/AI1/PV.CV'-'^/PREVIOUS_PV.CV') > DB then
# 	if '^/AI1/PV.CV' > '^/PREVIOUS_PV.CV' then
# 		'^/DIR_PV_CHG.CV':=1;(*PVIncreasing*)
# 	else
# 		'^/DIR_PV_CHG.CV':=2;(*PVDecreasing*)
# 	endif;
# 	'^/PREVIOUS_PV.CV':='^/AI1/PV.CV';
# endif;
#
# (* Simulation Logic *)
# if '^/AI1/SIMULATE.ENABLE' <> 2 then
# 	'IN1.CV':='^/AI1/PV.CV';
# 	'OUT1.CV' := FALSE;
# else
# 	'OUT1.CV' := TRUE;
# endif;
# if '^/AI1/L_TYPE.CV' = 1 (*Direct*) then
#     '^/AI1/SIMULATE_IN.CV' := 'IN1.CV';
#     'OUT2.CV' := '^/AI1/SIMULATE.FVALUE';
#     'OUT2.ST' := '^/AI1/SIMULATE.FSTATUS';
# endif;
# if '^/AI1/L_TYPE.CV' = 2 (*In-direct*) then
#     '^/AI1/SIMULATE_IN.CV' := ('IN1.CV'-'^/AI1/OUT_SCALE.EU0')/('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0') * 100;
#     'OUT2.CV' := ('^/AI1/SIMULATE.FVALUE'/100) * ('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0') + '^/AI1/OUT_SCALE.EU0';
#     'OUT2.ST' := '^/AI1/SIMULATE.FSTATUS';
# endif;
# if '^/AI1/L_TYPE.CV' = 3 (*Ind Sqr Root*) then
#     Temp := ('IN1.CV'-'^/AI1/OUT_SCALE.EU0')/('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0');
#     Temp := Temp * Temp;
#     '^/AI1/SIMULATE_IN.CV' := Temp * 100;
#     'OUT2.CV' := sqrt('^/AI1/SIMULATE.FVALUE'/100) * ('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0') + '^/AI1/OUT_SCALE.EU0';
#     'OUT2.ST' := '^/AI1/SIMULATE.FSTATUS';
# endif;
# '^/AI1/SIMULATE_IN.ST' := 128;
# (* End Simulation Logic *)" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   EXPOSED_PARAMETER NAME="AI1$ALARM_HYS" ID=2595746 PATH="AI1/ALARM_HYS" { }
#   EXPOSED_PARAMETER NAME="AI1$HI_HI_LIM" ID=2595737 PATH="AI1/HI_HI_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$HI_LIM" ID=2595738 PATH="AI1/HI_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$IO_IN" ID=2595735 PATH="AI1/IO_IN" { }
#   EXPOSED_PARAMETER NAME="AI1$IO_OPTS" ID=2595741 PATH="AI1/IO_OPTS" { }
#   EXPOSED_PARAMETER NAME="AI1$L_TYPE" ID=103351455 PATH="AI1/L_TYPE" { }
#   EXPOSED_PARAMETER NAME="AI1$LO_LIM" ID=2595739 PATH="AI1/LO_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$LO_LO_LIM" ID=2595740 PATH="AI1/LO_LO_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$LOW_CUT" ID=11379968 PATH="AI1/LOW_CUT" { }
#   EXPOSED_PARAMETER NAME="AI1$OUT_SCALE" ID=2595742 PATH="AI1/OUT_SCALE" { }
#   EXPOSED_PARAMETER NAME="AI1$PV_FTIME" ID=2595745 PATH="AI1/PV_FTIME" { }
#   EXPOSED_PARAMETER NAME="AI1$STATUS_OPTS" ID=11419425 PATH="AI1/STATUS_OPTS" { }
#   EXPOSED_PARAMETER NAME="AI1$STDEV_LIMIT" ID=366975828 PATH="AI1/STDEV_LIMIT" { }
#   EXPOSED_PARAMETER NAME="AI1$XD_SCALE" ID=6830783 PATH="AI1/XD_SCALE" { }
#   EXPOSED_PARAMETER NAME="DIR_PV_CHG_DB" ID=344791642 PATH="DIR_PV_CHG_DB" { }
#   EXPOSED_PARAMETER NAME="HI_ALARM$T_EXPRESSION" ID=17237942 PATH="HI_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="HI_ALM" ID=6348081 PATH="HI_ALM" { }
#   EXPOSED_PARAMETER NAME="HI_ALM_DELAY_OFF" ID=24250383 PATH="AI1/HI_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="HI_ALM_DELAY_ON" ID=24255341 PATH="AI1/HI_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="HI_ALM_ENAB_DELAY" ID=24264095 PATH="AI1/HI_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALARM$T_EXPRESSION" ID=17237966 PATH="HI_HI_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM" ID=6356694 PATH="HI_HI_ALM" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM_DELAY_OFF" ID=24151488 PATH="AI1/HI_HI_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM_DELAY_ON" ID=24168072 PATH="AI1/HI_HI_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM_ENAB_DELAY" ID=24186871 PATH="AI1/HI_HI_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="LO_ALARM$T_EXPRESSION" ID=17238010 PATH="LO_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="LO_ALM" ID=6362373 PATH="LO_ALM" { }
#   EXPOSED_PARAMETER NAME="LO_ALM_DELAY_OFF" ID=24322079 PATH="AI1/LO_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="LO_ALM_DELAY_ON" ID=24330121 PATH="AI1/LO_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="LO_ALM_ENAB_DELAY" ID=24339696 PATH="AI1/LO_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALARM$T_EXPRESSION" ID=17238104 PATH="LO_LO_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM" ID=6366751 PATH="LO_LO_ALM" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM_DELAY_OFF" ID=24395427 PATH="AI1/LO_LO_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM_DELAY_ON" ID=24404742 PATH="AI1/LO_LO_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM_ENAB_DELAY" ID=24414597 PATH="AI1/LO_LO_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="LOOP_DWG" ID=2392896146 PATH="LOOP_DWG" { }
#   EXPOSED_PARAMETER NAME="OPER_RANGE_HI" ID=143007470 PATH="OPER_RANGE_HI" { }
#   EXPOSED_PARAMETER NAME="OPER_RANGE_LO" ID=143007481 PATH="OPER_RANGE_LO" { }
#   EXPOSED_PARAMETER NAME="OPTM_RANGE_HI" ID=283717293 PATH="OPTM_RANGE_HI" { }
#   EXPOSED_PARAMETER NAME="OPTM_RANGE_LO" ID=283717294 PATH="OPTM_RANGE_LO" { }
#   EXPOSED_PARAMETER NAME="PID_DWG" ID=143007459 PATH="PID_DWG" { }
#   EXPOSED_PARAMETER NAME="PVBAD_ALM" ID=6370487 PATH="PVBAD_ALM" { }
#   EXPOSED_PARAMETER NAME="TRACKER_OP" ID=143007492 PATH="TRACKER_OP" { }
#   EXPOSED_PARAMETER NAME="VERSION" ID=2595736 PATH="VERSION" { }
# }
# MODULE_CLASS NAME="KS_AI_SIS_HH" CATEGORY="Library/Control Module Classes/KS_SCL_BMS"
#  user="KWK" time=1590703526/* "28-May-2020 16:05:26" */
# {
#   DESCRIPTION="SIS AI w/ conditional alarms, ext HH alarm limits"
#   PERIOD=1
#   PRIMARY_CONTROL_DISPLAY=""
#   INSTRUMENT_AREA_DISPLAY="KS_AI_fp"
#   DETAIL_DISPLAY="KS_Serial_AI_dt"
#   TYPE="A_FieldDevice"
#   SUB_TYPE="KS_AI_SIS_HH_"
#   NVM=F
#   FUNCTION_BLOCK NAME="PV-COMPARE" DEFINITION="CALC"
#   {
#     DESCRIPTION="Calc/Logic"
#     ID=142476998
#     RECTANGLE= { X=62 Y=642 H=37 W=130 }
#     SCAN_MULTIPLIER=5
#     EXTENSIBLE_ATTRIBUTE { NAME="OUT"  COUNT=1 }
#     EXTENSIBLE_ATTRIBUTE { NAME="IN"  COUNT=1 }
#   }
#   FUNCTION_BLOCK NAME="HI_HI_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=30270982
#     RECTANGLE= { X=290 Y=160 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="HI_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=32317050
#     RECTANGLE= { X=290 Y=230 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="LO_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=32334867
#     RECTANGLE= { X=290 Y=300 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="LO_LO_ALARM" DEFINITION="CND"
#   {
#     DESCRIPTION="Condition"
#     ID=32350742
#     RECTANGLE= { X=290 Y=370 H=56 W=120 }
#   }
#   FUNCTION_BLOCK NAME="AI1" DEFINITION="__5ED0355E_2784274A__"
#   {
#     DESCRIPTION="Analog Input with NO Real IO"
#     ID=2957100
#     RECTANGLE= { X=620 Y=90 H=316 W=170 }
#     ADDITIONAL_CONNECTOR NAME="PV" TYPE=OUTPUT { ATTRIBUTE="PV" }
#     ADDITIONAL_CONNECTOR NAME="HI_HI_LIM" TYPE=INPUT { ATTRIBUTE="HI_HI_LIM" }
#     ADDITIONAL_CONNECTOR NAME="HI_LIM" TYPE=INPUT { ATTRIBUTE="HI_LIM" }
#     ADDITIONAL_CONNECTOR NAME="LO_LIM" TYPE=INPUT { ATTRIBUTE="LO_LIM" }
#     ADDITIONAL_CONNECTOR NAME="LO_LO_LIM" TYPE=INPUT { ATTRIBUTE="LO_LO_LIM" }
#     ADDITIONAL_CONNECTOR NAME="OUT_SCALE" TYPE=INPUT { ATTRIBUTE="OUT_SCALE" }
#     ADDITIONAL_CONNECTOR NAME="XD_SCALE" TYPE=INPUT { ATTRIBUTE="XD_SCALE" }
#   }
#   ATTRIBUTE NAME="VERSION_CLASS" TYPE=UINT32
#   {
#     READONLY=T
#     EDITABLE=F
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#     GROUP="Operating"
#     HELP_ID=337653
#     CATEGORY { CATEGORY=ONLINE }
#   }
#   ATTRIBUTE NAME="HI_HI_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="HI_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="LO_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="LO_LO_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="PVBAD_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="IO_IN" TYPE=EXTERNAL_REFERENCE
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=290 Y=110 H=20 W=125 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="PID_DWG" TYPE=UNICODE_STRING
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=20 Y=130 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPER_RANGE_HI" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=22 Y=222 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPER_RANGE_LO" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=22 Y=242 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="TRACKER_OP" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=22 Y=462 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="DIR_PV_CHG" TYPE=FLOAT
#   {
#     CONNECTION=OUTPUT
#     RECTANGLE= { X=62 Y=552 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="DIR_PV_CHG_DB" TYPE=FLOAT
#   {
#     CONNECTION=OUTPUT
#     RECTANGLE= { X=62 Y=602 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="PREVIOUS_PV" TYPE=FLOAT
#   {
#     CONNECTION=OUTPUT
#     RECTANGLE= { X=62 Y=702 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPTM_RANGE_HI" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=20 Y=320 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="OPTM_RANGE_LO" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=20 Y=340 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="LOOP_DWG" TYPE=UNICODE_STRING
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=20 Y=150 H=20 W=130 }
#     GROUP="Configuration"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="HI_HI_LIM" TYPE=EXTERNAL_REFERENCE
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=290 Y=490 H=20 W=125 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="HI_LIM" TYPE=EXTERNAL_REFERENCE
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=290 Y=530 H=20 W=125 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="SCALE" TYPE=EXTERNAL_REFERENCE
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=290 Y=675 H=20 W=125 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="LO_LIM" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=290 Y=570 H=20 W=125 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="LO_LO_LIM" TYPE=FLOAT
#   {
#     CONNECTION=INPUT
#     RECTANGLE= { X=290 Y=610 H=20 W=125 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="BYPASS_ACTIVE" TYPE=BOOLEAN
#   {
#     CONNECTION=INTERNAL_SINK
#     RECTANGLE= { X=620 Y=790 H=20 W=110 }
#     GROUP="Alarm"
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="AVTR1_BYPASS1" TYPE=EXTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=300 Y=790 H=20 W=130 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   ATTRIBUTE NAME="BYPASS_ALRT" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="XMTR_FRZN_ALM" TYPE=EVENT
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=-50 Y=-50 H=1 W=1 }
#   }
#   ATTRIBUTE NAME="XMTR_FROZEN" TYPE=EXTERNAL_REFERENCE
#   {
#     CONNECTION=INTERNAL_SOURCE
#     RECTANGLE= { X=300 Y=850 H=20 W=130 }
#     CATEGORY { CATEGORY=COMMON }
#   }
#   FBD_ALGORITHM
#   {
#     GRAPHICS ALGORITHM=FBD
#     {
#       TEXT_GRAPHIC
#       {
#         NAME="0825FCA9"
#         ORIGIN= { X=624 Y=69 }
#         END= { X=843 Y=83 }
#         TEXT=" Analog Input monitoring module with alarms
# "
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{5ADE4BD3-C00A-486C-BEFE-7690FDB20FB0}"
#         RECTANGLE= { X=20 Y=70 H=10 W=180 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{1355024D-C5E9-40F8-B3BF-BC9155221FF6}"
#         ORIGIN= { X=26 Y=87 }
#         END= { X=190 Y=129 }
#         TEXT="This parameter is set to the P&ID
# Drawing that this equipment is
# found on."
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{0829A170-24FB-4E6D-9F6F-31F638715C57}"
#         ORIGIN= { X=26 Y=180 }
#         END= { X=154 Y=222 }
#         TEXT="Target/Operating Range
# Used to Display the Grey
# Box on the Graphics."
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{95645E77-82D9-4BB7-BAB5-8A7131774F60}"
#         RECTANGLE= { X=15 Y=390 H=10 W=185 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{0CED1249-17E9-4C7E-8531-C38318306A1F}"
#         ORIGIN= { X=26 Y=416 }
#         END= { X=163 Y=458 }
#         TEXT="Tracker/Expected Value
# Used to display line on the
# Graphic."
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{5CE10055-6295-419A-8146-8B9879F89309}"
#         RECTANGLE= { X=15 Y=490 H=10 W=185 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{2F3E1435-7437-4896-A329-95B5255B85BE}"
#         ORIGIN= { X=53 Y=503 }
#         END= { X=214 Y=548 }
#         TEXT="PV Direction Change Indication
# Used to show the up/down
# arrow on the graphics."
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{71AB3F22-C1A5-44B0-88C5-D7BCF5D6C773}"
#         ORIGIN= { X=52 Y=581 }
#         END= { X=201 Y=596 }
#         TEXT="Deadband in % of PV_SCALE"
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{36D69532-1DCA-4558-99AB-89793B681117}"
#         RECTANGLE= { X=200 Y=70 H=1110 W=10 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{8FA3E613-B22D-43F0-9E74-1A31261B9099}"
#         RECTANGLE= { X=15 Y=730 H=10 W=185 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=192 GREEN=192 BLUE=192 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{9A5D3C7A-6644-4DC4-8637-A0385268BBB3}"
#         RECTANGLE= { X=210 Y=730 H=10 W=1870 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{6EC7B293-AD5E-4A18-B2C8-3EEE9BC3B484}"
#         RECTANGLE= { X=970 Y=40 H=690 W=10 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       BOX_GRAPHIC
#       {
#         NAME="{09C5EF44-E390-4285-87D1-5BC55633551F}"
#         RECTANGLE= { X=1450 Y=45 H=685 W=10 }
#         LINE_STYLE=SOLID
#         LINE_WIDTH=1
#         LINE_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FGD_COLOR= { RED=239 GREEN=239 BLUE=239 }
#         BGD_COLOR= { RED=0 GREEN=0 BLUE=0 }
#         FILL_PATTERN=""
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{666DBB7E-38A9-424A-AD4E-C9E09010CA75}"
#         ORIGIN= { X=24 Y=278 }
#         END= { X=185 Y=320 }
#         TEXT="Optimal Range
# Used for Display of the upper
# and lower range on the graphic.  "
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{9A93C1CA-6E39-4F03-8113-713FAD077ED0}"
#         ORIGIN= { X=263 Y=457 }
#         END= { X=460 Y=485 }
#         TEXT="Link HI HI and HI Limits to SIS composite
# Configure LL LO Lims as required"
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{888B7F23-845B-4CD6-9495-4466C806996F}"
#         ORIGIN= { X=265 Y=656 }
#         END= { X=490 Y=670 }
#         TEXT="Link to LSAI OUT_SCALE within SIS Composite"
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{B23FF4FA-E0BE-4542-8337-BDFD14C23F97}"
#         ORIGIN= { X=252 Y=91 }
#         END= { X=477 Y=105 }
#         TEXT="Link to  OUT parameter within SIS Composite"
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{7EE73922-46B9-4E69-92D6-B649B2FD317E}"
#         ORIGIN= { X=271 Y=768 }
#         END= { X=596 Y=782 }
#         TEXT="Link to the BYPASS1 parameter of AVTR1 within the SIS composite"
#       }
#       TEXT_GRAPHIC
#       {
#         NAME="{F6880B80-4987-42C0-B8D1-5489C6901E25}"
#         ORIGIN= { X=273 Y=833 }
#         END= { X=611 Y=847 }
#         TEXT="Link to the XMTR_FROZEN_ALM within the SIS XMTR Alarm composite"
#       }
#     }
#     WIRE SOURCE="IO_IN" DESTINATION="AI1/IN"
#     {
#       ORIGIN_ID=338667148
#     }
#     WIRE SOURCE="HI_HI_ALARM/OUT_D" DESTINATION="AI1/HI_HI_ENABLE"
#     {
#       ORIGIN_ID=338667149
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=500 }
#     }
#     WIRE SOURCE="HI_ALARM/OUT_D" DESTINATION="AI1/HI_ENABLE"
#     {
#       ORIGIN_ID=338667150
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=510 }
#     }
#     WIRE SOURCE="LO_ALARM/OUT_D" DESTINATION="AI1/LO_ENABLE"
#     {
#       ORIGIN_ID=338667151
#     }
#     WIRE SOURCE="LO_LO_ALARM/OUT_D" DESTINATION="AI1/LO_LO_ENABLE"
#     {
#       ORIGIN_ID=338667152
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=530 }
#     }
#     WIRE SOURCE="HI_HI_LIM" DESTINATION="AI1/HI_HI_LIM"
#     {
#       ORIGIN_ID=338667153
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=550 }
#     }
#     WIRE SOURCE="HI_LIM" DESTINATION="AI1/HI_LIM"
#     {
#       ORIGIN_ID=338667154
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=560 }
#     }
#     WIRE SOURCE="SCALE" DESTINATION="AI1/OUT_SCALE"
#     {
#       ORIGIN_ID=338667155
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=590 }
#     }
#     WIRE SOURCE="SCALE" DESTINATION="AI1/XD_SCALE"
#     {
#       ORIGIN_ID=338667156
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=590 }
#     }
#     WIRE SOURCE="LO_LIM" DESTINATION="AI1/LO_LIM"
#     {
#       ORIGIN_ID=338667157
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=570 }
#     }
#     WIRE SOURCE="LO_LO_LIM" DESTINATION="AI1/LO_LO_LIM"
#     {
#       ORIGIN_ID=338667158
#       SEGMENT { INDEX=2 ORIENTATION=VERTICAL ORDINATE=580 }
#     }
#     WIRE SOURCE="AVTR1_BYPASS1" DESTINATION="BYPASS_ACTIVE"
#     {
#       ORIGIN_ID=338667159
#     }
#   }
#   ATTRIBUTE_INSTANCE NAME="MCOMMAND"
#   {
#     VALUE
#     {
#       SET="$module_states"
#       STRING_VALUE="In Service"
#       CHANGEABLE=F
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MSTATE"
#   {
#     VALUE
#     {
#       SET="$module_states"
#       STRING_VALUE="In Service"
#       CHANGEABLE=F
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MERROR"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_error_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MSTATUS"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_status_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MSTATUS_MASK"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_status_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="MERROR_MASK"
#   {
#     VALUE
#     {
#       ENUM_SET="$module_error_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="BAD_ACTIVE"
#   {
#     VALUE { CV=F }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="ABNORM_ACTIVE"
#   {
#     VALUE { CV=F }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="VERSION"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="BLOCK_ERR"
#   {
#     VALUE
#     {
#       ENUM_SET="$blk_err_opts"
#     }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="EXEC_TIME"
#   {
#     VALUE { CV=0 }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="ONTIME"
#   {
#     VALUE { CV=F }
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="VERSION_CLASS"
#   {
#     VALUE { CV=2 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=F
#       INV=F
#       ATYP="High High Alarm"
#       MONATTR=""
#       ALMATTR="AI1/HI_HI_ACT"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="MEDIUM"
#       ENAB=F
#       INV=F
#       ATYP="High Alarm"
#       MONATTR=""
#       ALMATTR="AI1/HI_ACT"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="MEDIUM"
#       ENAB=F
#       INV=F
#       ATYP="Low Alarm"
#       MONATTR=""
#       ALMATTR="AI1/LO_ACT"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=F
#       INV=F
#       ATYP="Low Low Alarm"
#       MONATTR=""
#       ALMATTR="AI1/LO_LO_ACT"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PVBAD_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=T
#       INV=F
#       ATYP="General I/O Failure"
#       MONATTR=""
#       ALMATTR="AI1/FAIL_ACTIVE"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="IO_IN"
#   {
#     VALUE { REF="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PID_DWG"
#   {
#     VALUE { CV="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPER_RANGE_HI"
#   {
#     VALUE { CV=100 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPER_RANGE_LO"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="TRACKER_OP"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="DIR_PV_CHG"
#   {
#     VALUE { CV=0 }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="DIR_PV_CHG_DB"
#   {
#     VALUE { CV=1 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PREVIOUS_PV"
#   {
#     VALUE { CV=0 }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPTM_RANGE_HI"
#   {
#     VALUE { CV=100 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPTM_RANGE_LO"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LOOP_DWG"
#   {
#     VALUE { CV="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_LIM"
#   {
#     VALUE { REF="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_LIM"
#   {
#     VALUE { REF="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="SCALE"
#   {
#     VALUE { REF="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LIM"
#   {
#     VALUE { CV=0 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_LIM"
#   {
#     VALUE { CV=0 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="BYPASS_ACTIVE"
#   {
#     VALUE { CV=F }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AVTR1_BYPASS1"
#   {
#     VALUE { REF="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
# ...
#     VALUE
#     {
#       PRIORITY_NAME="MEDIUM"
#       ENAB=F
#       INV=F
#       ATYP="High Alarm"
#       MONATTR=""
#       ALMATTR="AI1/HI_ACT"
#       LIMATTR="AI1/HI_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/HI_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="MEDIUM"
#       ENAB=F
#       INV=F
#       ATYP="Low Alarm"
#       MONATTR=""
#       ALMATTR="AI1/LO_ACT"
#       LIMATTR="AI1/LO_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/LO_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=F
#       INV=F
#       ATYP="Low Low Alarm"
#       MONATTR=""
#       ALMATTR="AI1/LO_LO_ACT"
#       LIMATTR="AI1/LO_LO_LIM"
#       PARAM1="AI1/OUT"
#       PARAM2="AI1/LO_LO_LIM"
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PVBAD_ALM"
#   {
#     VALUE
#     {
#       PRIORITY_NAME="CRITICAL"
#       ENAB=T
#       INV=F
#       ATYP="General I/O Failure"
#       MONATTR=""
#       ALMATTR="AI1/BAD_ACTIVE"
#       LIMATTR=""
#       PARAM1=""
#       PARAM2=""
#       SUPPTIMEOUT=240
#       MASK=65535
#       ISDEFAULTMASK=T
#       ALARM_FUNCTIONAL_CLASSIFICATION=0
#     }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PID_DWG"
#   {
#     VALUE { CV="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPER_RANGE_HI"
#   {
#     VALUE { CV=100 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPER_RANGE_LO"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="TRACKER_OP"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="DIR_PV_CHG"
#   {
#     VALUE { CV=0 }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="DIR_PV_CHG_DB"
#   {
#     VALUE { CV=1 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="PREVIOUS_PV"
#   {
#     VALUE { CV=0 }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPTM_RANGE_HI"
#   {
#     VALUE { CV=100 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="OPTM_RANGE_LO"
#   {
#     VALUE { CV=0 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="ALM_HYS"
#   {
#     VALUE { REF="AI1/ALARM_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALM_HYS"
#   {
#     VALUE { REF="AI1/HI_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALM_HYS"
#   {
#     VALUE { REF="AI1/HI_HI_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALM_HYS"
#   {
#     VALUE { REF="AI1/LO_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALM_HYS"
#   {
#     VALUE { REF="AI1/LO_LO_HYS" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LOOP_DWG"
#   {
#     VALUE { CV="" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/STATUS_OPTS"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/XD_SCALE"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/MODE"
#   {
#     VALUE
#     {
#       OOS_P=T
#       IMAN_P=F
#       LOV_P=F
#       MAN_P=F
#       AUTO_P=T
#       CAS_P=F
#       RCAS_P=F
#       ROUT_P=F
#       OOS_A=T
#       IMAN_A=F
#       LOV_A=F
#       MAN_A=T
#       AUTO_A=T
#       CAS_A=F
#       RCAS_A=F
#       ROUT_A=F
#       TARGET=AUTO
#       NORMAL=AUTO
#     }
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/OUT"
#   {
#     HISTORY_DATA_POINT FIELD="CV"
#     {
#       DATA_CHARACTERISTIC=CONTINUOUS
#       ENABLED=T
#       SAMPLE_PERIOD_SECONDS=2
#       COMPRESSION_ENABLED=T
#       RECORD_AT_LEAST_EVERY_MINUTES=1440
#       DEVIATION_LIMIT_FOR_COMPRESSION=0.02
#       DATA_REPRESENTATION=AUTOMATIC
#       EXPOSED=F
#       ENTERPRISE_COLLECTION=F
#     }
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/L_TYPE"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LOW_CUT"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LIM"
#   {
#     VALUE { CV=5 }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/BAD_MASK"
#   {
#     VALUE
#     {
#       ENUM_SET="$blk_err_opts"
#       OPTION8=T
#       OPTION15=T
#     }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/STDEV_LIMIT"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_HI_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LO_DELAY_OFF"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_HI_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LO_DELAY_ON"
#   {
#     VALUE { CV=3 }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_HI_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/HI_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="AI1/LO_LO_ENAB_DELAY"
#   {
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="HI_HI_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/DESC"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/T_EXPRESSION"
#   {
#     VALUE { TYPE=CONDITION EXPRESSION="NOT
# (False)
# (* Use this condition to disable the alarm.  When this
#    overall condition evaluates to False the alarm is disabled.
#
#    Replace the False inside of the () with conditions that
#    when evaluated to true will disable the alarm.
#
#    Also use the following parameters to complete the
#    conditional alarming:
#
#    alarm_ALM_ENAB_DELAY  (default 0 seconds)
#    alarm_ALM_DELAY_ON    (default 0 seconds)
#    alarm_ALM_DELAY_OFF   (default 0 seconds)
#    *)" }
#     EXPOSE=T
#     EXPOSE_IS_OVERRIDDEN=T
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/TIME_DURATION"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="LO_LO_ALARM/ERROR_OPT"
#   {
#     EXPOSE=F
#     EXPOSE_IS_OVERRIDDEN=T
#     HAS_DEFAULT_VALUE=T
#   }
#   ATTRIBUTE_INSTANCE NAME="PV-COMPARE/T_EXPRESSION"
#   {
#     VALUE { TYPE=EXPRESSION EXPRESSION="'^/DIR_PV_CHG.CV':=0;
# DB := ('^/DIR_PV_CHG_DB.CV'/100)*('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0');
# if abs('^/AI1/PV.CV'-'^/PREVIOUS_PV.CV') > DB then
# 	if '^/AI1/PV.CV' > '^/PREVIOUS_PV.CV' then
# 		'^/DIR_PV_CHG.CV':=1;(*PVIncreasing*)
# 	else
# 		'^/DIR_PV_CHG.CV':=2;(*PVDecreasing*)
# 	endif;
# 	'^/PREVIOUS_PV.CV':='^/AI1/PV.CV';
# endif;
#
# (* Simulation Logic *)
# if '^/AI1/SIMULATE.ENABLE' <> 2 then
# 	'IN1.CV':='^/AI1/PV.CV';
# 	'OUT1.CV' := FALSE;
# else
# 	'OUT1.CV' := TRUE;
# endif;
# if '^/AI1/L_TYPE.CV' = 1 (*Direct*) then
#     '^/AI1/SIMULATE_IN.CV' := 'IN1.CV';
#     'OUT2.CV' := '^/AI1/SIMULATE.FVALUE';
#     'OUT2.ST' := '^/AI1/SIMULATE.FSTATUS';
# endif;
# if '^/AI1/L_TYPE.CV' = 2 (*In-direct*) then
#     '^/AI1/SIMULATE_IN.CV' := ('IN1.CV'-'^/AI1/OUT_SCALE.EU0')/('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0') * 100;
#     'OUT2.CV' := ('^/AI1/SIMULATE.FVALUE'/100) * ('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0') + '^/AI1/OUT_SCALE.EU0';
#     'OUT2.ST' := '^/AI1/SIMULATE.FSTATUS';
# endif;
# if '^/AI1/L_TYPE.CV' = 3 (*Ind Sqr Root*) then
#     Temp := ('IN1.CV'-'^/AI1/OUT_SCALE.EU0')/('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0');
#     Temp := Temp * Temp;
#     '^/AI1/SIMULATE_IN.CV' := Temp * 100;
#     'OUT2.CV' := sqrt('^/AI1/SIMULATE.FVALUE'/100) * ('^/AI1/OUT_SCALE.EU100'-'^/AI1/OUT_SCALE.EU0') + '^/AI1/OUT_SCALE.EU0';
#     'OUT2.ST' := '^/AI1/SIMULATE.FSTATUS';
# endif;
# '^/AI1/SIMULATE_IN.ST' := 128;
# (* End Simulation Logic *)" }
#     VALUE_CHANGED=T
#     HAS_DEFAULT_VALUE=F
#   }
#   EXPOSED_PARAMETER NAME="AI1$ALARM_HYS" ID=2595746 PATH="AI1/ALARM_HYS" { }
#   EXPOSED_PARAMETER NAME="AI1$HI_HI_LIM" ID=2595737 PATH="AI1/HI_HI_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$HI_LIM" ID=2595738 PATH="AI1/HI_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$IO_IN" ID=2595735 PATH="AI1/IO_IN" { }
#   EXPOSED_PARAMETER NAME="AI1$IO_OPTS" ID=2595741 PATH="AI1/IO_OPTS" { }
#   EXPOSED_PARAMETER NAME="AI1$L_TYPE" ID=103351455 PATH="AI1/L_TYPE" { }
#   EXPOSED_PARAMETER NAME="AI1$LO_LIM" ID=2595739 PATH="AI1/LO_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$LO_LO_LIM" ID=2595740 PATH="AI1/LO_LO_LIM" { }
#   EXPOSED_PARAMETER NAME="AI1$LOW_CUT" ID=11379968 PATH="AI1/LOW_CUT" { }
#   EXPOSED_PARAMETER NAME="AI1$OUT_SCALE" ID=2595742 PATH="AI1/OUT_SCALE" { }
#   EXPOSED_PARAMETER NAME="AI1$PV_FTIME" ID=2595745 PATH="AI1/PV_FTIME" { }
#   EXPOSED_PARAMETER NAME="AI1$STATUS_OPTS" ID=11419425 PATH="AI1/STATUS_OPTS" { }
#   EXPOSED_PARAMETER NAME="AI1$STDEV_LIMIT" ID=366975828 PATH="AI1/STDEV_LIMIT" { }
#   EXPOSED_PARAMETER NAME="AI1$XD_SCALE" ID=6830783 PATH="AI1/XD_SCALE" { }
#   EXPOSED_PARAMETER NAME="DIR_PV_CHG_DB" ID=344791642 PATH="DIR_PV_CHG_DB" { }
#   EXPOSED_PARAMETER NAME="HI_ALARM$T_EXPRESSION" ID=17237942 PATH="HI_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="HI_ALM" ID=6348081 PATH="HI_ALM" { }
#   EXPOSED_PARAMETER NAME="HI_ALM_DELAY_OFF" ID=24250383 PATH="AI1/HI_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="HI_ALM_DELAY_ON" ID=24255341 PATH="AI1/HI_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="HI_ALM_ENAB_DELAY" ID=24264095 PATH="AI1/HI_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALARM$T_EXPRESSION" ID=17237966 PATH="HI_HI_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM" ID=6356694 PATH="HI_HI_ALM" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM_DELAY_OFF" ID=24151488 PATH="AI1/HI_HI_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM_DELAY_ON" ID=24168072 PATH="AI1/HI_HI_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="HI_HI_ALM_ENAB_DELAY" ID=24186871 PATH="AI1/HI_HI_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="LO_ALARM$T_EXPRESSION" ID=17238010 PATH="LO_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="LO_ALM" ID=6362373 PATH="LO_ALM" { }
#   EXPOSED_PARAMETER NAME="LO_ALM_DELAY_OFF" ID=24322079 PATH="AI1/LO_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="LO_ALM_DELAY_ON" ID=24330121 PATH="AI1/LO_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="LO_ALM_ENAB_DELAY" ID=24339696 PATH="AI1/LO_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALARM$T_EXPRESSION" ID=17238104 PATH="LO_LO_ALARM/T_EXPRESSION" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM" ID=6366751 PATH="LO_LO_ALM" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM_DELAY_OFF" ID=24395427 PATH="AI1/LO_LO_DELAY_OFF" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM_DELAY_ON" ID=24404742 PATH="AI1/LO_LO_DELAY_ON" { }
#   EXPOSED_PARAMETER NAME="LO_LO_ALM_ENAB_DELAY" ID=24414597 PATH="AI1/LO_LO_ENAB_DELAY" { }
#   EXPOSED_PARAMETER NAME="LOOP_DWG" ID=2392896146 PATH="LOOP_DWG" { }
#   EXPOSED_PARAMETER NAME="OPER_RANGE_HI" ID=143007470 PATH="OPER_RANGE_HI" { }
#   EXPOSED_PARAMETER NAME="OPER_RANGE_LO" ID=143007481 PATH="OPER_RANGE_LO" { }
#   EXPOSED_PARAMETER NAME="OPTM_RANGE_HI" ID=283717293 PATH="OPTM_RANGE_HI" { }
#   EXPOSED_PARAMETER NAME="OPTM_RANGE_LO" ID=283717294 PATH="OPTM_RANGE_LO" { }
#   EXPOSED_PARAMETER NAME="PID_DWG" ID=143007459 PATH="PID_DWG" { }
#   EXPOSED_PARAMETER NAME="PVBAD_ALM" ID=6370487 PATH="PVBAD_ALM" { }
#   EXPOSED_PARAMETER NAME="TRACKER_OP" ID=143007492 PATH="TRACKER_OP" { }
#   EXPOSED_PARAMETER NAME="VERSION" ID=2595736 PATH="VERSION" { }
# }

# %%
#Module Class - Main Module
MC_name=[]
pattern = re.compile(r"MODULE_CLASS NAME=\W(.+)\W\sC+")
match_MC = pattern.finditer(data)
for i in match_MC:
    MC_name.append(i.group(1))
Module_Class = pd.DataFrame(MC_name,columns=["Module_Class"])
Module_Class
# Out:
#    Module_Class
# 0     KS_AI_STD
# 1  KS_AI_SIS_HH
# 2     KS_AI_STD

# %%
#Module_Instance_Name
MI_name=[]
pattern = re.compile(r"MODULE_INSTANCE TAG=\W(.+)\W\sPL")
match_MI = pattern.finditer(data)
for i in match_MI:
    MI_name.append(i.group(1))
Module_Instance=pd.DataFrame(MI_name,columns=["Module_Instance"])
Module_Instance
# Out:
#   Module_Instance
# 0       TI_580920
# 1      PI_580911B

# %%
#Function Class and Defination
fb_names =[]
defi=[]
pattern = re.compile(r"FUNCTION_BLOCK NAME=\W(.+)\W\sDEFINITION=\W(.+)\W")
match_FB = pattern.finditer(data)
for i in match_FB:
    fb_names.append(i.group(1))
    defi.append(i.group(2))
    
#len(fb_names)
#len(defi)
FC = pd.DataFrame(columns = ['Function_Block_Name','Defination'])
FC["Function_Block_Name"]=fb_names
FC["Defination"]=defi
FC
# Out:
#    Function_Block_Name              Defination
# 0           PV-COMPARE                   CALC"
# 1          HI_HI_ALARM                    CND"
# 2             HI_ALARM                    CND"
# 3             LO_ALARM                    CND"
# 4          LO_LO_ALARM                    CND"
# 5                  AI1              AIWCALARM"
# 6           PV-COMPARE                   CALC"
# 7          HI_HI_ALARM                    CND"
# 8             HI_ALARM                    CND"
# 9             LO_ALARM                    CND"
# 10         LO_LO_ALARM                    CND"
# 11                 AI1  __5ED0355E_2784274A__"
# 12                 AI2                     AI"
# 13          PV-COMPARE                   CALC"
# 14         HI_HI_ALARM                    CND"
# 15            HI_ALARM                    CND"
# 16            LO_ALARM                    CND"
# 17         LO_LO_ALARM                    CND"
# 18                ADD1                    ADD"
# 19             AGA_US1                 AGA_US"
# 20                 AI1  __5DF27C84_007821F1__"
# 21          PV-COMPARE                   CALC"
# 22         DV_HI_ALARM                    CND"
# 23         DV_LO_ALARM                    CND"
# 24         HI_HI_ALARM                    CND"
# 25            HI_ALARM                    CND"
# 26            LO_ALARM                    CND"
# 27         LO_LO_ALARM                    CND"
# 28             PV_CALC  __5EDD5F76_112E5D7E__"
# 29                CND1                    CND"
# ..                 ...                     ...
# 68                PDE1                    PDE"
# 69                ACT1                    ACT"
# 70               SCLR1                   SCLR"
# 71                 BG1                     BG"
# 72               CALC1                   CALC"
# 73                CND1                    CND"
# 74                CND4                    CND"
# 75               RTLM2                   RTLM"
# 76               RTLM1                   RTLM"
# 77                CND2                    CND"
# 78                PDE1                    PDE"
# 79                ACT1                    ACT"
# 80         CROSS_LIMIT            CROSS_LIMIT"
# 81             FUEL_SP  __5ED68511_2D968C5E__"
# 82            CG_CURVE                   SGCR"
# 83            OG_CURVE                   SGCR"
# 84                ADD1                    ADD"
# 85          BKCAL_CALC                   CALC"
# 86           VIV_CURVE                   SGCR"
# 87           FGR_CURVE                   SGCR"
# 88           AIR_CURVE                   SGCR"
# 89                CND3                    CND"
# 90                PDE2                    PDE"
# 91                ACT2                    ACT"
# 92          PV-COMPARE                   CALC"
# 93         HI_HI_ALARM                    CND"
# 94            HI_ALARM                    CND"
# 95            LO_ALARM                    CND"
# 96         LO_LO_ALARM                    CND"
# 97                 AI1              AIWCALARM"
#
# [98 rows x 2 columns]

# %%
#WIRE SOURCE=\W(.+)\W DESTINATION=\W(.+)\W
#Wire Source and Destination
ws =[]
des=[]
pattern = re.compile(r"WIRE SOURCE=\W(.+)\W DESTINATION=\W(.+)\W")
match_WSD = pattern.finditer(data)
for i in match_WSD:
    ws.append(i.group(1))
    des.append(i.group(2))
    
WS = pd.DataFrame(columns = ['Wire_Source','Destination'])
WS["Wire_Source"]=ws
WS["Destination"]=des
WS
# Out:
#              Wire_Source              Destination
# 0                ALM_HYS           HI_HI_ALM_HYS"
# 1                ALM_HYS              HI_ALM_HYS"
# 2                ALM_HYS              LO_ALM_HYS"
# 3                ALM_HYS           LO_LO_ALM_HYS"
# 4      HI_HI_ALARM/OUT_D          AI1/HI_HI_ENAB"
# 5         HI_ALARM/OUT_D             AI1/HI_ENAB"
# 6         LO_ALARM/OUT_D             AI1/LO_ENAB"
# 7      LO_LO_ALARM/OUT_D          AI1/LO_LO_ENAB"
# 8                  IO_IN                  AI1/IN"
# 9      HI_HI_ALARM/OUT_D        AI1/HI_HI_ENABLE"
# 10        HI_ALARM/OUT_D           AI1/HI_ENABLE"
# 11        LO_ALARM/OUT_D           AI1/LO_ENABLE"
# 12     LO_LO_ALARM/OUT_D        AI1/LO_LO_ENABLE"
# 13             HI_HI_LIM           AI1/HI_HI_LIM"
# 14                HI_LIM              AI1/HI_LIM"
# 15                 SCALE           AI1/OUT_SCALE"
# 16                 SCALE            AI1/XD_SCALE"
# 17                LO_LIM              AI1/LO_LIM"
# 18             LO_LO_LIM           AI1/LO_LO_LIM"
# 19         AVTR1_BYPASS1           BYPASS_ACTIVE"
# 20     HI_HI_ALARM/OUT_D        AI1/HI_HI_ENABLE"
# 21        HI_ALARM/OUT_D           AI1/HI_ENABLE"
# 22        LO_ALARM/OUT_D           AI1/LO_ENABLE"
# 23     LO_LO_ALARM/OUT_D        AI1/LO_LO_ENABLE"
# 24               AI2/OUT              AGA_US1/IN"
# 25              ADD1/OUT         AGA_US1/PRES_IN"
# 26              PRESS_IN                ADD1/IN1"
# 27               TEMP_IN         AGA_US1/TEMP_IN"
# 28     AGA_US1/VOL_FLW_B                  AI1/IN"
# 29                 P_ATM                ADD1/IN2"
# ..                   ...                      ...
# 113      FGR_CURVE/OUT_1      FGR_FLOW/REMOTE_SP"
# 114      VIV_CURVE/OUT_1        VIV_DAMPER/INPUT"
# 115      AIR_CURVE/OUT_1        AIR_DAMPER/INPUT"
# 116            RTLM1/OUT          AIR_CURVE/IN_1"
# 117          TUNING_MODE  AIR_DAMPER/TUNING_MODE"
# 118          TUNING_MODE    FGR_FLOW/TUNING_MODE"
# 119          TUNING_MODE     AIR_PID/TUNING_MODE"
# 120          TUNING_MODE  VIV_DAMPER/TUNING_MODE"
# 121          TUNING_MODE   OUTER_GAS/TUNING_MODE"
# 122          TUNING_MODE  CENTER_GAS/TUNING_MODE"
# 123       CG_CURVE/OUT_1    CENTER_GAS/REMOTE_SP"
# 124  CROSS_LIMIT/FUEL_SP           CG_CURVE/IN_1"
# 125       OG_CURVE/OUT_1     OUTER_GAS/REMOTE_SP"
# 126  CROSS_LIMIT/FUEL_SP           OG_CURVE/IN_1"
# 127           CND3/OUT_D               PDE2/IN_D"
# 128           PDE2/OUT_D               ACT2/IN_D"
# 129              BG1/OUT                RTLM2/IN"
# 130            RTLM2/OUT                RTLM1/IN"
# 131           CND4/OUT_D            RTLM2/ENABLE"
# 132           CALC1/OUT1                BKCALOUT"
# 133              BG1/OUT               CALC1/IN1"
# 134        BG1/BKCAL_OUT               CALC1/IN2"
# 135              ALM_HYS           HI_HI_ALM_HYS"
# 136              ALM_HYS              HI_ALM_HYS"
# 137              ALM_HYS              LO_ALM_HYS"
# 138              ALM_HYS           LO_LO_ALM_HYS"
# 139    HI_HI_ALARM/OUT_D          AI1/HI_HI_ENAB"
# 140       HI_ALARM/OUT_D             AI1/HI_ENAB"
# 141       LO_ALARM/OUT_D             AI1/LO_ENAB"
# 142    LO_LO_ALARM/OUT_D          AI1/LO_LO_ENAB"
#
# [143 rows x 2 columns]

# %%
#Main 
#Module Class - Main Module
#Module_Instance_Name
#Function Class and Defination
#Wire Source and Destination

MC_name=[]

MI_name=[]

fb_names =[]
defi=[]

ws =[]
des=[]

pattern = re.compile(r"MODULE_CLASS NAME=\W(.+)\W\sC+")
match_MC = pattern.finditer(data)
for i in match_MC:
    MC_name.append(i.group(1))
Module_Class = pd.DataFrame(MC_name,columns=["Module_Class"])
#Module_Class

pattern1 = re.compile(r"MODULE_INSTANCE TAG=\W(.+)\W\sPL")
match_MI = pattern1.finditer(data)
for i in match_MI:
    MI_name.append(i.group(1))
Module_Instance=pd.DataFrame(MI_name,columns=["Module_Instance"])
#Module_Instance

pattern2 = re.compile(r"FUNCTION_BLOCK NAME=\W(.+)\W\sDEFINITION=\W(.+)\W")
match_FB = pattern2.finditer(data)
for i in match_FB:
    fb_names.append(i.group(1))
    defi.append(i.group(2))

FC = pd.DataFrame(columns = ['Function_Block_Name','Defination'])
FC["Function_Block_Name"]=fb_names
FC["Defination"]=defi
#FC


pattern = re.compile(r"WIRE SOURCE=\W(.+)\W DESTINATION=\W(.+)\W")
match_WSD = pattern.finditer(data)
for i in match_WSD:
    ws.append(i.group(1))
    des.append(i.group(2))
    
WS = pd.DataFrame(columns = ['Wire_Source','Destination'])
WS["Wire_Source"]=ws
WS["Destination"]=des
#WS
